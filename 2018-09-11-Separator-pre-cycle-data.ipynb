# %% [markdown]
# # Separator PSU precycle data
#
# We now analyse some data from the separator PSU pre cycle. The DAQ is set to gather 100 samples at 100Hz so recieve new data ever second. The timestamps for this data are generated by the EPICS IOC when it processes the data.
